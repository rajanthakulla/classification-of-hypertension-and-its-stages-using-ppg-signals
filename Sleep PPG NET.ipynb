# %%
# !pip install numpy pandas tensorflow matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\divgy\anaconda3\lib\site-packages (1.23.5)
# Requirement already satisfied: pandas in c:\users\divgy\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: tensorflow in c:\users\divgy\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: matplotlib in c:\users\divgy\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\divgy\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\divgy\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: setuptools in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.11)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: packaging in c:\users\divgy\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\divgy\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\divgy\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.11.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\divgy\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\divgy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\divgy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\divgy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\divgy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.19.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\divgy\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\divgy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\divgy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\divgy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\divgy\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\divgy\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divgy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2023.7.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\divgy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\divgy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\divgy\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\divgy\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\divgy\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Load CSV file
data = pd.read_csv('standardised_dataset.csv',header=None)

# %%
data
# Out:
#           0         1         2         3         4         5         6     \
# 0    -0.325484 -0.325926 -0.152455 -0.144238 -0.136613 -0.304554 -0.299140
# 1    -0.129219 -0.112576 -0.107353 -0.099354 -0.110948 -0.105894 -0.111175
# 2     0.334095  0.359380  0.363002  0.301392  0.309305  0.313855  0.446349
# 3    -0.598968 -0.600695 -0.568043 -0.557808 -0.479873 -0.474377 -0.467991
# 4     0.163570  0.165426  0.269576  0.275744  0.184191  0.188891  0.191481
# ...        ...       ...       ...       ...       ...       ...       ...
# 1966  0.668711  0.672940  0.675499  0.634813  0.642941  0.605436  0.605642
# 1967  0.437054  0.482218  0.485424  0.314216  0.322137  0.326672  0.302986
# 1968 -0.290092 -0.290368 -0.284541 -0.323772 -0.316263 -0.291738 -0.286397
# 1969 -0.608620 -0.610393 -0.603481 -0.564220 -0.556866 -0.541665 -0.534894
# 1970  0.250441  0.246240  0.250246  0.256508  0.241936  0.246567  0.239269
#
#           7         8         9     ...      2091      2092      2093  \
# 0    -0.147937 -0.142891 -0.133432  ...  0.419156  0.463063  0.463679
# 1    -0.109532 -0.104428 -0.069556  ...  0.076667  0.071583  0.070139
# 2     0.450549  0.357126  0.364803  ... -0.028715 -0.033689 -0.191118
# 3    -0.480785 -0.476235 -0.491140  ...  0.241325  0.242650  0.242106
# 4     0.197713  0.203275  0.316896  ... -0.219718 -0.224494 -0.227496
# ...        ...       ...       ...  ...       ...       ...       ...
# 1966  0.610572  0.568671  0.575595  ...  1.258913  1.262472  1.267294
# 1967  0.306528  0.302637  0.310508  ...  0.168875  0.163696  0.013919
# 1968 -0.285557 -0.248663 -0.238828  ...  0.359879  0.354502  0.285098
# 1969 -0.535193 -0.489056 -0.478364  ...  0.794577  0.788749  0.741472
# 1970  0.242519  0.248148  0.336059  ... -0.430481 -0.435038 -0.439147
#
#           2094      2095      2096      2097      2098      2099  2100
# 0     0.402541  0.405764  0.412294  0.293141  0.292716  0.332797     2
# 1     0.165051  0.168331  0.286329  0.283272  0.282837  0.177171     2
# 2    -0.191184 -0.187819 -0.035212 -0.035830 -0.115613 -0.117527     1
# 3     0.250811  0.254071  0.259810  0.230636  0.230149  0.263262     1
# 4    -0.267049 -0.263666 -0.320290 -0.318744 -0.319778 -0.339378     1
# ...        ...       ...       ...       ...       ...       ...   ...
# 1966  1.263441  1.216995  1.227750  1.359005  1.359639  1.365894     3
# 1967  0.013321  0.016637 -0.041842 -0.042409  0.072086  0.071212     3
# 1968  0.283796  0.326620  0.332737  0.329328  0.272958  0.273196     3
# 1969  0.738985  0.653091  0.660909  0.655008  0.641771  0.644051     3
# 1970 -0.445166 -0.441741 -0.598739 -0.595079 -0.596388 -0.511561     3
#
# [1971 rows x 2101 columns]

# %%
# Assuming the PPG signals are in the first 3840 columns and the label is in the last column
X = data.iloc[:, :2099].values
y = data.iloc[:, -1].values

# %%
X.shape
# Out:
# (1971, 2099)

# %%
# Encode labels to integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Reshape data to fit the model input shape (samples, timesteps, features)
X = X.reshape((X.shape[0], X.shape[1], 1))

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=None)

# Visualize the first PPG signal
plt.figure(figsize=(10, 4))
plt.plot(X_train[409])
plt.title("First PPG Signal")
plt.xlabel("samples")
plt.ylabel("Amplitude")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Model

from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Dense, Dropout, BatchNormalization, Activation, Add, TimeDistributed, Reshape, GlobalAveragePooling1D, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train.shape
# Out:
# (1379, 2099, 1)

# %%
# # Define Residual Block
# def residual_block(x, filters, kernel_size, dilation_rate=1):
#     shortcut = x
#     x = Conv1D(filters, kernel_size, padding='same', dilation_rate=dilation_rate)(x)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = Conv1D(filters, kernel_size, padding='same', dilation_rate=dilation_rate)(x)
#     x = BatchNormalization()(x)
#     x = Add()([shortcut, x])
#     x = Activation('relu')(x)
#     return x

# # Define SleepPPG-Net Model
# input_shape = (3840, 1)  # Each row has 3840 time steps (representing 30 seconds), and 1 feature per time step
# inputs = Input(shape=input_shape)

# # Feature Extraction (8 Residual Convolutional Blocks)
# x = inputs
# filter_sizes = [16, 16, 32, 32, 64, 64, 128, 256]
# for filters in filter_sizes:
#     x = Conv1D(filters, 3, padding='same', activation='relu')(x)
#     x = MaxPooling1D(pool_size=2)(x)

# # Windowing
# x = Reshape((-1, 256))(x)  # Adjusting based on input/output dimensions in the image

# # Time Distributed Dense Layer
# x = TimeDistributed(Dense(128, activation='relu'))(x)

# # Temporal Convolutional Network (Dilated Convolutions)
# for i in [1, 2, 4, 8, 16, 32]:
#     x = Conv1D(128, 7, padding='same', dilation_rate=i, activation='relu')(x)
#     x = Dropout(0.2)(x)

# # Global Average Pooling to produce a single vector
# x = GlobalAveragePooling1D()(x)

# # Final Classification Layer
# outputs = Dense(7, activation='softmax')(x)  # Adjusted for 6 classes

# # Define Model
# model = Model(inputs=inputs, outputs=outputs)

# # Compile Model
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model.summary()

# %%
# Define Residual Block with Shape Matching
def residual_block(x, filters, kernel_size):
    shortcut = Conv1D(filters, 1, padding='same')(x)  # Ensure the shortcut has the same number of filters
    for _ in range(3):
        x = Conv1D(filters, kernel_size, padding='same')(x)
        x = BatchNormalization()(x)
        x = LeakyReLU(alpha=0.01)(x)
    x = Add()([shortcut, x])
    x = MaxPooling1D(pool_size=2)(x)
    return x

# Define TCN Block
def tcn_block(x, filters, kernel_size, dilation_rates):
    for dilation_rate in dilation_rates:
        shortcut = x
        x = Conv1D(filters, kernel_size, padding='same', dilation_rate=dilation_rate)(x)
        x = BatchNormalization()(x)
        x = LeakyReLU(alpha=0.01)(x)
        x = Dropout(0.2)(x)
        x = Add()([shortcut, x])
    return x

# Define SleepPPG-Net Model
input_shape = (2099, 1)  # Adjust to match your data dimensions
inputs = Input(shape=input_shape)

# Feature Extraction (8 Residual Convolutional Blocks)
x = inputs
filter_sizes = [16, 16, 32, 32, 64, 64, 128, 256]
for filters in filter_sizes:
    x = residual_block(x, filters, 3)

# Windowing
x = Reshape((-1, 256))(x)  # Adjusting based on input/output dimensions in the image

# Time Distributed Dense Layer
x = TimeDistributed(Dense(128, activation='relu'))(x)

# Temporal Convolutional Network (2 TCN Blocks)
for _ in range(2):
    x = tcn_block(x, 128, 5, [1, 2, 4, 8, 16])

# Final Classification Layer
x = Conv1D(4, 1, activation='softmax')(x)  # Adjusted for 6 classes

# Define Model
model = Model(inputs=inputs, outputs=x)

# Compile Model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 2099, 1)]    0           []
#
#  conv1d_173 (Conv1D)            (None, 2099, 16)     64          ['input_5[0][0]']
#
#  batch_normalization_136 (Batch  (None, 2099, 16)    64          ['conv1d_173[0][0]']
#  Normalization)
#
#  leaky_re_lu_136 (LeakyReLU)    (None, 2099, 16)     0           ['batch_normalization_136[0][0]']
#
#  conv1d_174 (Conv1D)            (None, 2099, 16)     784         ['leaky_re_lu_136[0][0]']
#
#  batch_normalization_137 (Batch  (None, 2099, 16)    64          ['conv1d_174[0][0]']
#  Normalization)
#
#  leaky_re_lu_137 (LeakyReLU)    (None, 2099, 16)     0           ['batch_normalization_137[0][0]']
#
#  conv1d_175 (Conv1D)            (None, 2099, 16)     784         ['leaky_re_lu_137[0][0]']
#
#  batch_normalization_138 (Batch  (None, 2099, 16)    64          ['conv1d_175[0][0]']
#  Normalization)
#
#  conv1d_172 (Conv1D)            (None, 2099, 16)     32          ['input_5[0][0]']
#
#  leaky_re_lu_138 (LeakyReLU)    (None, 2099, 16)     0           ['batch_normalization_138[0][0]']
#
#  add_72 (Add)                   (None, 2099, 16)     0           ['conv1d_172[0][0]',
#                                                                   'leaky_re_lu_138[0][0]']
#
#  max_pooling1d_32 (MaxPooling1D  (None, 1049, 16)    0           ['add_72[0][0]']
#  )
#
#  conv1d_177 (Conv1D)            (None, 1049, 16)     784         ['max_pooling1d_32[0][0]']
#
#  batch_normalization_139 (Batch  (None, 1049, 16)    64          ['conv1d_177[0][0]']
#  Normalization)
#
#  leaky_re_lu_139 (LeakyReLU)    (None, 1049, 16)     0           ['batch_normalization_139[0][0]']
#
#  conv1d_178 (Conv1D)            (None, 1049, 16)     784         ['leaky_re_lu_139[0][0]']
#
#  batch_normalization_140 (Batch  (None, 1049, 16)    64          ['conv1d_178[0][0]']
#  Normalization)
#
#  leaky_re_lu_140 (LeakyReLU)    (None, 1049, 16)     0           ['batch_normalization_140[0][0]']
#
#  conv1d_179 (Conv1D)            (None, 1049, 16)     784         ['leaky_re_lu_140[0][0]']
#
#  batch_normalization_141 (Batch  (None, 1049, 16)    64          ['conv1d_179[0][0]']
#  Normalization)
#
#  conv1d_176 (Conv1D)            (None, 1049, 16)     272         ['max_pooling1d_32[0][0]']
#
#  leaky_re_lu_141 (LeakyReLU)    (None, 1049, 16)     0           ['batch_normalization_141[0][0]']
#
#  add_73 (Add)                   (None, 1049, 16)     0           ['conv1d_176[0][0]',
#                                                                   'leaky_re_lu_141[0][0]']
#
#  max_pooling1d_33 (MaxPooling1D  (None, 524, 16)     0           ['add_73[0][0]']
#  )
#
#  conv1d_181 (Conv1D)            (None, 524, 32)      1568        ['max_pooling1d_33[0][0]']
#
#  batch_normalization_142 (Batch  (None, 524, 32)     128         ['conv1d_181[0][0]']
#  Normalization)
#
#  leaky_re_lu_142 (LeakyReLU)    (None, 524, 32)      0           ['batch_normalization_142[0][0]']
#
#  conv1d_182 (Conv1D)            (None, 524, 32)      3104        ['leaky_re_lu_142[0][0]']
#
#  batch_normalization_143 (Batch  (None, 524, 32)     128         ['conv1d_182[0][0]']
#  Normalization)
#
#  leaky_re_lu_143 (LeakyReLU)    (None, 524, 32)      0           ['batch_normalization_143[0][0]']
#
#  conv1d_183 (Conv1D)            (None, 524, 32)      3104        ['leaky_re_lu_143[0][0]']
#
#  batch_normalization_144 (Batch  (None, 524, 32)     128         ['conv1d_183[0][0]']
#  Normalization)
#
#  conv1d_180 (Conv1D)            (None, 524, 32)      544         ['max_pooling1d_33[0][0]']
#
#  leaky_re_lu_144 (LeakyReLU)    (None, 524, 32)      0           ['batch_normalization_144[0][0]']
#
#  add_74 (Add)                   (None, 524, 32)      0           ['conv1d_180[0][0]',
#                                                                   'leaky_re_lu_144[0][0]']
#
#  max_pooling1d_34 (MaxPooling1D  (None, 262, 32)     0           ['add_74[0][0]']
#  )
#
#  conv1d_185 (Conv1D)            (None, 262, 32)      3104        ['max_pooling1d_34[0][0]']
#
#  batch_normalization_145 (Batch  (None, 262, 32)     128         ['conv1d_185[0][0]']
#  Normalization)
#
#  leaky_re_lu_145 (LeakyReLU)    (None, 262, 32)      0           ['batch_normalization_145[0][0]']
#
#  conv1d_186 (Conv1D)            (None, 262, 32)      3104        ['leaky_re_lu_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 262, 32)     128         ['conv1d_186[0][0]']
#  Normalization)
#
#  leaky_re_lu_146 (LeakyReLU)    (None, 262, 32)      0           ['batch_normalization_146[0][0]']
#
#  conv1d_187 (Conv1D)            (None, 262, 32)      3104        ['leaky_re_lu_146[0][0]']
#
#  batch_normalization_147 (Batch  (None, 262, 32)     128         ['conv1d_187[0][0]']
#  Normalization)
#
#  conv1d_184 (Conv1D)            (None, 262, 32)      1056        ['max_pooling1d_34[0][0]']
#
#  leaky_re_lu_147 (LeakyReLU)    (None, 262, 32)      0           ['batch_normalization_147[0][0]']
#
#  add_75 (Add)                   (None, 262, 32)      0           ['conv1d_184[0][0]',
#                                                                   'leaky_re_lu_147[0][0]']
#
#  max_pooling1d_35 (MaxPooling1D  (None, 131, 32)     0           ['add_75[0][0]']
#  )
#
#  conv1d_189 (Conv1D)            (None, 131, 64)      6208        ['max_pooling1d_35[0][0]']
#
#  batch_normalization_148 (Batch  (None, 131, 64)     256         ['conv1d_189[0][0]']
#  Normalization)
#
#  leaky_re_lu_148 (LeakyReLU)    (None, 131, 64)      0           ['batch_normalization_148[0][0]']
#
#  conv1d_190 (Conv1D)            (None, 131, 64)      12352       ['leaky_re_lu_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 131, 64)     256         ['conv1d_190[0][0]']
#  Normalization)
#
#  leaky_re_lu_149 (LeakyReLU)    (None, 131, 64)      0           ['batch_normalization_149[0][0]']
#
#  conv1d_191 (Conv1D)            (None, 131, 64)      12352       ['leaky_re_lu_149[0][0]']
#
#  batch_normalization_150 (Batch  (None, 131, 64)     256         ['conv1d_191[0][0]']
#  Normalization)
#
#  conv1d_188 (Conv1D)            (None, 131, 64)      2112        ['max_pooling1d_35[0][0]']
#
#  leaky_re_lu_150 (LeakyReLU)    (None, 131, 64)      0           ['batch_normalization_150[0][0]']
#
#  add_76 (Add)                   (None, 131, 64)      0           ['conv1d_188[0][0]',
#                                                                   'leaky_re_lu_150[0][0]']
#
#  max_pooling1d_36 (MaxPooling1D  (None, 65, 64)      0           ['add_76[0][0]']
#  )
#
#  conv1d_193 (Conv1D)            (None, 65, 64)       12352       ['max_pooling1d_36[0][0]']
#
#  batch_normalization_151 (Batch  (None, 65, 64)      256         ['conv1d_193[0][0]']
#  Normalization)
#
#  leaky_re_lu_151 (LeakyReLU)    (None, 65, 64)       0           ['batch_normalization_151[0][0]']
#
#  conv1d_194 (Conv1D)            (None, 65, 64)       12352       ['leaky_re_lu_151[0][0]']
#
#  batch_normalization_152 (Batch  (None, 65, 64)      256         ['conv1d_194[0][0]']
#  Normalization)
#
#  leaky_re_lu_152 (LeakyReLU)    (None, 65, 64)       0           ['batch_normalization_152[0][0]']
#
#  conv1d_195 (Conv1D)            (None, 65, 64)       12352       ['leaky_re_lu_152[0][0]']
#  batch_normalization_153 (Batch  (None, 65, 64)      256         ['conv1d_195[0][0]']
#  Normalization)
#
#  conv1d_192 (Conv1D)            (None, 65, 64)       4160        ['max_pooling1d_36[0][0]']
#
#  leaky_re_lu_153 (LeakyReLU)    (None, 65, 64)       0           ['batch_normalization_153[0][0]']
#
#  add_77 (Add)                   (None, 65, 64)       0           ['conv1d_192[0][0]',
#                                                                   'leaky_re_lu_153[0][0]']
#
#  max_pooling1d_37 (MaxPooling1D  (None, 32, 64)      0           ['add_77[0][0]']
#  )
#
#  conv1d_197 (Conv1D)            (None, 32, 128)      24704       ['max_pooling1d_37[0][0]']
#
#  batch_normalization_154 (Batch  (None, 32, 128)     512         ['conv1d_197[0][0]']
#  Normalization)
#
#  leaky_re_lu_154 (LeakyReLU)    (None, 32, 128)      0           ['batch_normalization_154[0][0]']
#
#  conv1d_198 (Conv1D)            (None, 32, 128)      49280       ['leaky_re_lu_154[0][0]']
#
#  batch_normalization_155 (Batch  (None, 32, 128)     512         ['conv1d_198[0][0]']
#  Normalization)
#
#  leaky_re_lu_155 (LeakyReLU)    (None, 32, 128)      0           ['batch_normalization_155[0][0]']
#
#  conv1d_199 (Conv1D)            (None, 32, 128)      49280       ['leaky_re_lu_155[0][0]']
#
#  batch_normalization_156 (Batch  (None, 32, 128)     512         ['conv1d_199[0][0]']
#  Normalization)
#
#  conv1d_196 (Conv1D)            (None, 32, 128)      8320        ['max_pooling1d_37[0][0]']
#
#  leaky_re_lu_156 (LeakyReLU)    (None, 32, 128)      0           ['batch_normalization_156[0][0]']
#
#  add_78 (Add)                   (None, 32, 128)      0           ['conv1d_196[0][0]',
#                                                                   'leaky_re_lu_156[0][0]']
#
#  max_pooling1d_38 (MaxPooling1D  (None, 16, 128)     0           ['add_78[0][0]']
#  )
#
#  conv1d_201 (Conv1D)            (None, 16, 256)      98560       ['max_pooling1d_38[0][0]']
#
#  batch_normalization_157 (Batch  (None, 16, 256)     1024        ['conv1d_201[0][0]']
#  Normalization)
#
#  leaky_re_lu_157 (LeakyReLU)    (None, 16, 256)      0           ['batch_normalization_157[0][0]']
#
#  conv1d_202 (Conv1D)            (None, 16, 256)      196864      ['leaky_re_lu_157[0][0]']
#
#  batch_normalization_158 (Batch  (None, 16, 256)     1024        ['conv1d_202[0][0]']
#  Normalization)
#
#  leaky_re_lu_158 (LeakyReLU)    (None, 16, 256)      0           ['batch_normalization_158[0][0]']
#
#  conv1d_203 (Conv1D)            (None, 16, 256)      196864      ['leaky_re_lu_158[0][0]']
#
#  batch_normalization_159 (Batch  (None, 16, 256)     1024        ['conv1d_203[0][0]']
#  Normalization)
#
#  conv1d_200 (Conv1D)            (None, 16, 256)      33024       ['max_pooling1d_38[0][0]']
#
#  leaky_re_lu_159 (LeakyReLU)    (None, 16, 256)      0           ['batch_normalization_159[0][0]']
#
#  add_79 (Add)                   (None, 16, 256)      0           ['conv1d_200[0][0]',
#                                                                   'leaky_re_lu_159[0][0]']
#
#  max_pooling1d_39 (MaxPooling1D  (None, 8, 256)      0           ['add_79[0][0]']
#  )
#
#  reshape_4 (Reshape)            (None, 8, 256)       0           ['max_pooling1d_39[0][0]']
#
#  time_distributed_4 (TimeDistri  (None, 8, 128)      32896       ['reshape_4[0][0]']
#  buted)
#
#  conv1d_204 (Conv1D)            (None, 8, 128)       82048       ['time_distributed_4[0][0]']
#
#  batch_normalization_160 (Batch  (None, 8, 128)      512         ['conv1d_204[0][0]']
#  Normalization)
#
#  leaky_re_lu_160 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_160[0][0]']
#  dropout_40 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_160[0][0]']
#
#  add_80 (Add)                   (None, 8, 128)       0           ['time_distributed_4[0][0]',
#                                                                   'dropout_40[0][0]']
#
#  conv1d_205 (Conv1D)            (None, 8, 128)       82048       ['add_80[0][0]']
#
#  batch_normalization_161 (Batch  (None, 8, 128)      512         ['conv1d_205[0][0]']
#  Normalization)
#
#  leaky_re_lu_161 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_161[0][0]']
#
#  dropout_41 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_161[0][0]']
#
#  add_81 (Add)                   (None, 8, 128)       0           ['add_80[0][0]',
#                                                                   'dropout_41[0][0]']
#
#  conv1d_206 (Conv1D)            (None, 8, 128)       82048       ['add_81[0][0]']
#
#  batch_normalization_162 (Batch  (None, 8, 128)      512         ['conv1d_206[0][0]']
#  Normalization)
#
#  leaky_re_lu_162 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_162[0][0]']
#
#  dropout_42 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_162[0][0]']
#
#  add_82 (Add)                   (None, 8, 128)       0           ['add_81[0][0]',
#                                                                   'dropout_42[0][0]']
#
#  conv1d_207 (Conv1D)            (None, 8, 128)       82048       ['add_82[0][0]']
#
#  batch_normalization_163 (Batch  (None, 8, 128)      512         ['conv1d_207[0][0]']
#  Normalization)
#
#  leaky_re_lu_163 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_163[0][0]']
#
#  dropout_43 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_163[0][0]']
#
#  add_83 (Add)                   (None, 8, 128)       0           ['add_82[0][0]',
#                                                                   'dropout_43[0][0]']
#
#  conv1d_208 (Conv1D)            (None, 8, 128)       82048       ['add_83[0][0]']
#
#  batch_normalization_164 (Batch  (None, 8, 128)      512         ['conv1d_208[0][0]']
#  Normalization)
#
#  leaky_re_lu_164 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_164[0][0]']
#
#  dropout_44 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_164[0][0]']
#
#  add_84 (Add)                   (None, 8, 128)       0           ['add_83[0][0]',
#                                                                   'dropout_44[0][0]']
#
#  conv1d_209 (Conv1D)            (None, 8, 128)       82048       ['add_84[0][0]']
#
#  batch_normalization_165 (Batch  (None, 8, 128)      512         ['conv1d_209[0][0]']
#  Normalization)
#
#  leaky_re_lu_165 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_165[0][0]']
#
#  dropout_45 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_165[0][0]']
#
#  add_85 (Add)                   (None, 8, 128)       0           ['add_84[0][0]',
#                                                                   'dropout_45[0][0]']
#
#  conv1d_210 (Conv1D)            (None, 8, 128)       82048       ['add_85[0][0]']
#
#  batch_normalization_166 (Batch  (None, 8, 128)      512         ['conv1d_210[0][0]']
#  Normalization)
#
#  leaky_re_lu_166 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_166[0][0]']
#
#  dropout_46 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_166[0][0]']
#
#  add_86 (Add)                   (None, 8, 128)       0           ['add_85[0][0]',
#                                                                   'dropout_46[0][0]']
#
#  conv1d_211 (Conv1D)            (None, 8, 128)       82048       ['add_86[0][0]']
#
#  batch_normalization_167 (Batch  (None, 8, 128)      512         ['conv1d_211[0][0]']
#  Normalization)
#
#  leaky_re_lu_167 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_167[0][0]']
#
#  dropout_47 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_167[0][0]']
#
#  add_87 (Add)                   (None, 8, 128)       0           ['add_86[0][0]',
#                                                                   'dropout_47[0][0]']
#
#  conv1d_212 (Conv1D)            (None, 8, 128)       82048       ['add_87[0][0]']
#
#  batch_normalization_168 (Batch  (None, 8, 128)      512         ['conv1d_212[0][0]']
#  Normalization)
#
#  leaky_re_lu_168 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_168[0][0]']
#
#  dropout_48 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_168[0][0]']
#
#  add_88 (Add)                   (None, 8, 128)       0           ['add_87[0][0]',
#                                                                   'dropout_48[0][0]']
#
#  conv1d_213 (Conv1D)            (None, 8, 128)       82048       ['add_88[0][0]']
#
#  batch_normalization_169 (Batch  (None, 8, 128)      512         ['conv1d_213[0][0]']
#  Normalization)
#
#  leaky_re_lu_169 (LeakyReLU)    (None, 8, 128)       0           ['batch_normalization_169[0][0]']
#
#  dropout_49 (Dropout)           (None, 8, 128)       0           ['leaky_re_lu_169[0][0]']
#
#  add_89 (Add)                   (None, 8, 128)       0           ['add_88[0][0]',
#                                                                   'dropout_49[0][0]']
#
#  conv1d_214 (Conv1D)            (None, 8, 4)         516         ['add_89[0][0]']
#
# ==================================================================================================
# Total params: 1,620,420
# Trainable params: 1,614,212
# Non-trainable params: 6,208
# __________________________________________________________________________________________________

# %%
# Assuming each sequence has 15 time steps and the same label for all time steps
sequence_length = model.output_shape[1]  # This should be 15 based on your model architecture

# Repeat the target label for each time step
y_train_seq = np.repeat(y_train[:, np.newaxis], sequence_length, axis=1)
y_test_seq = np.repeat(y_test[:, np.newaxis], sequence_length, axis=1)

# %%
y_train_seq.shape
# Out:
# (1379, 8)

# %%
from tensorflow.keras.models import load_model

# %%
# model = load_model('sleepppgnet_model_with_earlystopping.h5')

# # Define EarlyStopping callback
# early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, min_delta=0.001)

# history_continued = model.fit(X_train, y_train_seq, epochs=80, batch_size=8, validation_data=(X_test, y_test_seq), callbacks=[early_stopping])

# # Step 3: Combine training histories (optional)
# history.history['loss'].extend(history_continued.history['loss'])
# history.history['val_loss'].extend(history_continued.history['val_loss'])
# history.history['accuracy'].extend(history_continued.history['accuracy'])
# history.history['val_accuracy'].extend(history_continued.history['val_accuracy'])
# # Step 4: Save the model again if needed 
# model.save('sleepppgnet_model_updated.h5')

# %%
import numpy as np

# Sample numpy array for y_test (replace this with your actual y_test array)
# y_test = np.array([...])

# Count the number of occurrences of each unique label
unique, counts = np.unique(y_test, return_counts=True)
label_counts = dict(zip(unique, counts))

# Print the count of each label
for label, count in label_counts.items():
    print(f"Label {label}: {count} occurrences")
# Out:
# Label 0: 220 occurrences
# Label 1: 212 occurrences
# Label 2: 101 occurrences
# Label 3: 59 occurrences

# %%
# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True, min_delta=0.01)

# Train the model with EarlyStopping
history = model.fit(X_train, y_train_seq, epochs=100, batch_size=8, validation_data=(X_test, y_test_seq))


# Save the model
model.save('sleepppgnet_model_with_earlystopping_again_100.h5')
# Out:
# Epoch 1/100
# 173/173 [==============================] - 63s 196ms/step - loss: 2.0415 - accuracy: 0.3684 - val_loss: 1.5911 - val_accuracy: 0.3581
# Epoch 2/100
# 173/173 [==============================] - 33s 191ms/step - loss: 1.6489 - accuracy: 0.3889 - val_loss: 2.5509 - val_accuracy: 0.3744
# Epoch 3/100
# 173/173 [==============================] - 38s 220ms/step - loss: 1.5386 - accuracy: 0.4022 - val_loss: 2.7022 - val_accuracy: 0.3955
# Epoch 4/100
# 173/173 [==============================] - 44s 253ms/step - loss: 1.5362 - accuracy: 0.3844 - val_loss: 1.3229 - val_accuracy: 0.3982
# Epoch 5/100
# 173/173 [==============================] - 45s 261ms/step - loss: 1.4746 - accuracy: 0.4021 - val_loss: 1.3321 - val_accuracy: 0.3925
# Epoch 6/100
# 173/173 [==============================] - 43s 251ms/step - loss: 1.4296 - accuracy: 0.3981 - val_loss: 1.3624 - val_accuracy: 0.3813
# Epoch 7/100
# 173/173 [==============================] - 43s 247ms/step - loss: 1.4334 - accuracy: 0.3770 - val_loss: 1.5817 - val_accuracy: 0.3712
# Epoch 8/100
# 173/173 [==============================] - 42s 243ms/step - loss: 1.4395 - accuracy: 0.3825 - val_loss: 2.2858 - val_accuracy: 0.3190
# Epoch 9/100
# 173/173 [==============================] - 40s 231ms/step - loss: 1.3798 - accuracy: 0.3794 - val_loss: 1.4221 - val_accuracy: 0.3486
# Epoch 10/100
# 173/173 [==============================] - 37s 212ms/step - loss: 1.3591 - accuracy: 0.3949 - val_loss: 1.2757 - val_accuracy: 0.3758
# Epoch 11/100
# 173/173 [==============================] - 36s 211ms/step - loss: 1.3409 - accuracy: 0.3971 - val_loss: 1.4861 - val_accuracy: 0.3148
# Epoch 12/100
# 173/173 [==============================] - 36s 210ms/step - loss: 1.3526 - accuracy: 0.3829 - val_loss: 1.3199 - val_accuracy: 0.3459
# Epoch 13/100
# 173/173 [==============================] - 36s 209ms/step - loss: 1.3463 - accuracy: 0.3913 - val_loss: 1.4805 - val_accuracy: 0.3594
# Epoch 14/100
# 173/173 [==============================] - 36s 209ms/step - loss: 1.3749 - accuracy: 0.3895 - val_loss: 1.3545 - val_accuracy: 0.3775
# Epoch 15/100
# 173/173 [==============================] - 34s 194ms/step - loss: 1.2845 - accuracy: 0.4243 - val_loss: 1.2918 - val_accuracy: 0.4088
# Epoch 16/100
# 173/173 [==============================] - 32s 184ms/step - loss: 1.2698 - accuracy: 0.4288 - val_loss: 1.4336 - val_accuracy: 0.4117
# Epoch 17/100
# 173/173 [==============================] - 37s 214ms/step - loss: 1.2820 - accuracy: 0.4410 - val_loss: 1.2339 - val_accuracy: 0.4160
# Epoch 18/100
# 173/173 [==============================] - 37s 213ms/step - loss: 1.2654 - accuracy: 0.4146 - val_loss: 1.3598 - val_accuracy: 0.3596
# Epoch 19/100
# 173/173 [==============================] - 38s 219ms/step - loss: 1.2283 - accuracy: 0.4378 - val_loss: 1.2399 - val_accuracy: 0.4155
# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\divgy\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\divgy\anaconda3\lib\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\divgy\anaconda3\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\divgy\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\divgy\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\divgy\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\divgy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
# Predict the labels on the test set
# model = load_model('sleepppgnet_model_with_earlystopping_again.h5')
y_pred = model.predict(X_train)
y_pred_classes = np.argmax(y_pred, axis=2).flatten()
y_test_flat = y_train_seq.flatten()

# Calculate accuracy
accuracy = accuracy_score(y_test_flat, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')

# Confusion matrix
conf_matrix = confusion_matrix(y_test_flat, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 44/44 [==============================] - 7s 112ms/step
# Accuracy: 0.9695

# %%
plt.figure(figsize=(12,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Train','Validation'], loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'history' object is available from model training

# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# Assuming 'model' and 'X_train' are defined and trained

# Predict the labels on the training set
y_pred_train = model.predict(X_train)
y_pred_classes_train = np.argmax(y_pred_train, axis=2).flatten()

# Flatten the true labels
y_train_flat = y_train_seq.flatten()

# Calculate confusion matrix
conf_matrix_train = confusion_matrix(y_train_flat, y_pred_classes_train)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', 
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Training Set')
plt.show()
# Out:
# 44/44 [==============================] - 5s 105ms/step

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming conf_matrix_train is already computed as per the previous code snippet

# Compute precision, recall, and F1-score for each class
precision = precision_score(y_train_flat, y_pred_classes_train, average=None)
recall = recall_score(y_train_flat, y_pred_classes_train, average=None)
f1 = f1_score(y_train_flat, y_pred_classes_train, average=None)

# Print precision, recall, and F1-score for each class
for i in range(len(label_encoder.classes_)):
    print(f"Class '{label_encoder.classes_[i]}' - Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1-score: {f1[i]:.4f}")
# Out:
# Class '0' - Precision: 0.9945, Recall: 0.9477, F1-score: 0.9706
# Class '1' - Precision: 0.9584, Recall: 0.9903, F1-score: 0.9741
# Class '2' - Precision: 0.9357, Recall: 0.9677, F1-score: 0.9514
# Class '3' - Precision: 0.9832, Recall: 0.9680, F1-score: 0.9755

# %%
def aggregate_predictions(model, X_test, y_test_seq):
    # Predict the probabilities for the test set
    y_pred = model.predict(X_test)
   
    # Aggregate predictions by averaging probabilities across all time steps
    avg_probabilities = np.mean(y_pred, axis=1)
    final_predictions = np.argmax(avg_probabilities, axis=1)
   
    # Get the true labels for the test set
    true_labels = y_test_seq[:, 0]  # All time steps have the same label, so we take the first one
   
    return final_predictions, true_labels

# Get the aggregated predictions and true labels
final_predictions, true_labels = aggregate_predictions(model, X_test, y_test_seq)

# Calculate accuracy
accuracy = accuracy_score(true_labels, final_predictions)
print(f'Accuracy: {accuracy:.4f}')

# Confusion matrix
conf_matrix = confusion_matrix(true_labels, final_predictions)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 19/19 [==============================] - 2s 110ms/step
# Accuracy: 0.8480
